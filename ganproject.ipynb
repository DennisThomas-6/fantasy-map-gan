# %%
# !pip install torch torchvision matplotlib pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 46.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-58b9017b-7f4f-4187-bcf9-20d6fbb38556" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58b9017b-7f4f-4187-bcf9-20d6fbb38556">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import os

# ✅ Your folder name
input_folder = '/content/fantasy_maps1'
output_folder = '/content/fantasy_maps1_resized'
size = (128, 128)

os.makedirs(output_folder, exist_ok=True)

count = 0
for file_name in os.listdir(input_folder):
    if file_name.endswith(".png") or file_name.endswith(".jpg"):
        img = Image.open(os.path.join(input_folder, file_name)).convert("RGB")
        img = img.resize(size)
        img.save(os.path.join(output_folder, file_name))
        count += 1

print(f"Resized {count} images.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-18-3695125916.py in <cell line: 0>()
#      10
#      11 count = 0
# ---> 12 for file_name in os.listdir(input_folder):
#      13     if file_name.endswith(".png") or file_name.endswith(".jpg"):
#      14         img = Image.open(os.path.join(input_folder, file_name)).convert("RGB")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/fantasy_maps1'

# %%
from google.colab import files
import os

# Create a clean folder to store uploaded images
upload_dir = '/content/fantasy_maps_uploaded'
os.makedirs(upload_dir, exist_ok=True)

uploaded = files.upload()

# Save uploaded files into your folder
for file_name in uploaded.keys():
    os.rename(file_name, os.path.join(upload_dir, file_name))

print("Upload complete!")
print("Files in folder:", os.listdir(upload_dir))
# Out:
#      <input type="file" id="files-2e8299e7-e75b-4e83-a19e-1b4419452e72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e8299e7-e75b-4e83-a19e-1b4419452e72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import os

input_folder = '/content/fantasy_maps_uploaded'
output_folder = '/content/fantasy_maps_resized'
size = (128, 128)

os.makedirs(output_folder, exist_ok=True)

count = 0
for file_name in os.listdir(input_folder):
    if file_name.endswith(".png") or file_name.endswith(".jpg"):
        img = Image.open(os.path.join(input_folder, file_name)).convert("RGB")
        img = img.resize(size)
        img.save(os.path.join(output_folder, file_name))
        count += 1

print(f"Resized {count} images.")
# Out:
# Resized 40 images.

# %%
print(os.listdir('/content/fantasy_maps_resized'))
# Out:
# ['Best-Fantasy-Map-Generators-3-1024x576 (1).jpg', '2KkNFMvWSMgAK2m-s7pjAQ73zqWSYbtZttBeYW6VUrA (2).jpg', '360_F_577865351_InslhXO8VcD93BIMLjsa205eyIKvC9HC (1).jpg', '62f3402a7b9c5fd63abd2773cb06793158d2fd67 (1).jpg', 'Blog-Size-Scale+(Small) (1).jpg', '507076 (1).png', '360_F_172071155_8rqqSiDYitjR6a54ljrtsh4OvR8uwv7v (1).jpg', '71y79RcNAuL (1).jpg', 'c2ee086a089c2af40c9470c676bf2ab2a992a972 (1).jpg', '71p2jP8dd2L (1).jpg', 'Best-Fantasy-Map-Generators-4-1024x576 (1).jpg', '71PQpR7MHTL (1).jpg', '3XoLcxgZiiuui69amJzV7XqslhMsFHzH0ArVem1eIR8 (1).jpg', '4a94b7a8b4b088bdd4d72d906bbb0933c35a27d0 (1).jpg']

# %%
from PIL import Image
import os

input_folder = '/content/fantasy_maps_uploaded'
output_folder = '/content/fantasy_maps_resized'
size = (128, 128)

os.makedirs(output_folder, exist_ok=True)

count = 0
for file_name in os.listdir(input_folder):
    if file_name.endswith(".png") or file_name.endswith(".jpg"):
        img = Image.open(os.path.join(input_folder, file_name)).convert("RGB")
        img = img.resize(size)
        img.save(os.path.join(output_folder, file_name))
        count += 1

print(f"Resized {count} images.")
# Out:
# Resized 40 images.

# %%
import os
import shutil

# Folder where resized images are saved
resized_folder = '/content/fantasy_maps_resized'

# Create a class folder inside resized folder
maps_class_folder = os.path.join(resized_folder, 'maps')
os.makedirs(maps_class_folder, exist_ok=True)

# Move all images into the class folder
for file_name in os.listdir(resized_folder):
    file_path = os.path.join(resized_folder, file_name)
    if os.path.isfile(file_path):
        shutil.move(file_path, os.path.join(maps_class_folder, file_name))

print("All images moved into a single class folder.")
# Out:
# All images moved into a single class folder.

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

transform = transforms.Compose([
    transforms.Resize(128),
    transforms.CenterCrop(128),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset = datasets.ImageFolder(
    root='/content/fantasy_maps_resized',
    transform=transform
)

dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

print(f"Loaded {len(dataset)} images into DataLoader.")
# Out:
# Loaded 40 images into DataLoader.

# %%
import torch
import torch.nn as nn

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(100, 512, 4, 1, 0, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(True),

            nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),

            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),

            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),

            nn.ConvTranspose2d(64, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, input):
        return self.main(input)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(256, 512, 4, 2, 1, bias=False),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(512, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input).view(-1, 1).squeeze(1)

# %%
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

netG = Generator().to(device)
netD = Discriminator().to(device)

criterion = nn.BCELoss()

optimizerD = optim.Adam(netD.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=0.0002, betas=(0.5, 0.999))

fixed_noise = torch.randn(16, 100, 1, 1, device=device)

print("Models ready!")
# Out:
# Models ready!

# %%
num_epochs = 30

for epoch in range(num_epochs):
    for i, (data, _) in enumerate(dataloader):
        real_imgs = data.to(device)
        b_size = real_imgs.size(0)
        real_labels = torch.full((b_size,), 1., device=device)
        fake_labels = torch.full((b_size,), 0., device=device)

        # Train Discriminator
        netD.zero_grad()
        output_real = netD(real_imgs)
        loss_real = criterion(output_real, real_labels)

        noise = torch.randn(b_size, 100, 1, 1, device=device)
        fake_imgs = netG(noise)
        output_fake = netD(fake_imgs.detach())
        loss_fake = criterion(output_fake, fake_labels)

        loss_D = loss_real + loss_fake
        loss_D.backward()
        optimizerD.step()

        # Train Generator
        netG.zero_grad()
        output = netD(fake_imgs)
        loss_G = criterion(output, real_labels)
        loss_G.backward()
        optimizerG.step()

    print(f"Epoch [{epoch+1}/{num_epochs}] Loss_D: {loss_D.item():.4f} Loss_G: {loss_G.item():.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-28-126295609.py in <cell line: 0>()
#      11         netD.zero_grad()
#      12         output_real = netD(real_imgs)
# ---> 13         loss_real = criterion(output_real, real_labels)
#      14
#      15         noise = torch.randn(b_size, 100, 1, 1, device=device)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
# ...

# %%
num_epochs = 50

for epoch in range(num_epochs):
    for i, (data, _) in enumerate(dataloader):
        real_imgs = data.to(device)
        output_real = netD(real_imgs).view(-1)

        real_labels = torch.ones_like(output_real, device=device)
        fake_labels = torch.zeros_like(output_real, device=device)

        # --- Train Discriminator ---
        netD.zero_grad()
        loss_real = criterion(output_real, real_labels)

        noise = torch.randn(real_imgs.size(0), 100, 1, 1, device=device)
        fake_imgs = netG(noise)
        output_fake = netD(fake_imgs.detach()).view(-1)
        loss_fake = criterion(output_fake, fake_labels)

        loss_D = loss_real + loss_fake
        loss_D.backward()
        optimizerD.step()

        # --- Train Generator ---
        netG.zero_grad()
        output = netD(fake_imgs).view(-1)
        loss_G = criterion(output, real_labels)
        loss_G.backward()
        optimizerG.step()

    print(f"Epoch [{epoch+1}/{num_epochs}] Loss_D: {loss_D.item():.4f} Loss_G: {loss_G.item():.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-29-2793087529.py in <cell line: 0>()
#      16         fake_imgs = netG(noise)
#      17         output_fake = netD(fake_imgs.detach()).view(-1)
# ---> 18         loss_fake = criterion(output_fake, fake_labels)
#      19
#      20         loss_D = loss_real + loss_fake
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
# ...

# %%
num_epochs = 50

for epoch in range(num_epochs):
    for i, (data, _) in enumerate(dataloader):
        real_imgs = data.to(device)

        # --- Train Discriminator ---
        netD.zero_grad()

        output_real = netD(real_imgs).view(-1)
        real_labels = torch.ones_like(output_real, device=device)
        loss_real = criterion(output_real, real_labels)

        noise = torch.randn(real_imgs.size(0), 100, 1, 1, device=device)
        fake_imgs = netG(noise)
        output_fake = netD(fake_imgs.detach()).view(-1)
        fake_labels = torch.zeros_like(output_fake, device=device)
        loss_fake = criterion(output_fake, fake_labels)

        loss_D = loss_real + loss_fake
        loss_D.backward()
        optimizerD.step()

        # --- Train Generator ---
        netG.zero_grad()
        output = netD(fake_imgs).view(-1)
        real_labels_for_G = torch.ones_like(output, device=device)
        loss_G = criterion(output, real_labels_for_G)
        loss_G.backward()
        optimizerG.step()

    print(f"Epoch [{epoch+1}/{num_epochs}] Loss_D: {loss_D.item():.4f} Loss_G: {loss_G.item():.4f}")
# Out:
# Epoch [1/50] Loss_D: 0.7430 Loss_G: 5.1077
# Epoch [2/50] Loss_D: 0.3495 Loss_G: 5.7832
# Epoch [3/50] Loss_D: 0.2512 Loss_G: 7.0974
# Epoch [4/50] Loss_D: 0.1680 Loss_G: 7.5335
# Epoch [5/50] Loss_D: 0.1776 Loss_G: 8.2557
# Epoch [6/50] Loss_D: 0.1543 Loss_G: 8.7609
# Epoch [7/50] Loss_D: 0.1161 Loss_G: 8.9774
# Epoch [8/50] Loss_D: 0.0660 Loss_G: 7.5623
# Epoch [9/50] Loss_D: 0.0631 Loss_G: 7.6942
# Epoch [10/50] Loss_D: 0.0461 Loss_G: 8.2784
# Epoch [11/50] Loss_D: 0.0402 Loss_G: 8.1505
# Epoch [12/50] Loss_D: 0.0364 Loss_G: 8.3298
# Epoch [13/50] Loss_D: 0.0418 Loss_G: 8.0685
# Epoch [14/50] Loss_D: 0.0298 Loss_G: 8.4363
# Epoch [15/50] Loss_D: 0.0460 Loss_G: 8.3908
# Epoch [16/50] Loss_D: 0.0176 Loss_G: 7.9249
# Epoch [17/50] Loss_D: 0.0280 Loss_G: 7.9940
# Epoch [18/50] Loss_D: 0.0314 Loss_G: 8.8393
# Epoch [19/50] Loss_D: 0.0259 Loss_G: 8.6632
# Epoch [20/50] Loss_D: 0.0103 Loss_G: 9.3118
# Epoch [21/50] Loss_D: 0.0162 Loss_G: 9.4564
# ...

# %%
import torchvision.utils as vutils
import matplotlib.pyplot as plt

with torch.no_grad():
    fake_imgs = netG(fixed_noise).detach().cpu()

grid = vutils.make_grid(fake_imgs, nrow=4, normalize=True)
plt.figure(figsize=(8,8))
plt.imshow(grid.permute(1, 2, 0))
plt.axis('off')
plt.show()

# %%
import torchvision.utils as vutils
import matplotlib.pyplot as plt

# Create random noise
noise = torch.randn(16, 100, 1, 1, device=device)

# Generate images
with torch.no_grad():
    fake_imgs = netG(noise).detach().cpu()

# Create a grid of images
grid = vutils.make_grid(fake_imgs, nrow=4, normalize=True)

# Display the grid
plt.figure(figsize=(8, 8))
plt.imshow(grid.permute(1, 2, 0))
plt.axis('off')
plt.show()

# %%
import torchvision.utils as vutils
import matplotlib.pyplot as plt

# Create random noise
noise = torch.randn(16, 100, 1, 1, device=device)

# Generate images
with torch.no_grad():
    fake_imgs = netG(noise).detach().cpu()

# Create a grid of images
grid = vutils.make_grid(fake_imgs, nrow=4, normalize=True)

# Display the grid
plt.figure(figsize=(8, 8))
plt.imshow(grid.permute(1, 2, 0))
plt.axis('off')
plt.show()
